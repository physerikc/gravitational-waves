# %% [markdown]
# first we will install some dependences and import the necessary libraries

# %%
# !pip install --upgrade astropy
# !pip install --upgrade matplotlib
# !pip install --upgrade scipy
# !pip install --upgrade gwpy
# Out:
# Requirement already satisfied: astropy in c:\users\erick\anaconda3\lib\site-packages (6.1.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\erick\anaconda3\lib\site-packages (from astropy) (1.26.4)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\erick\anaconda3\lib\site-packages (from astropy) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.8.27.10.28.29 in c:\users\erick\anaconda3\lib\site-packages (from astropy) (0.2024.9.30.0.32.59)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\erick\anaconda3\lib\site-packages (from astropy) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in c:\users\erick\anaconda3\lib\site-packages (from astropy) (23.1)
# Requirement already satisfied: matplotlib in c:\users\erick\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\erick\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scipy in c:\users\erick\anaconda3\lib\site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\erick\anaconda3\lib\site-packages (from scipy) (1.26.4)
# Requirement already satisfied: gwpy in c:\users\erick\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: astropy>=4.3.0 in c:\users\erick\anaconda3\lib\site-packages (from gwpy) (6.1.4)
# Requirement already satisfied: dateparser>=1.1.4 in c:\users\erick\anaconda3\lib\site-packages (from gwpy) (1.2.0)
# Requirement already satisfied: dqsegdb2 in c:\users\erick\anaconda3\lib\site-packages (from gwpy) (1.2.1)
# Requirement already satisfied: gwdatafind>=1.1.0 in c:\users\erick\anaconda3\lib\site-packages (from gwpy) (1.2.0)
# Requirement already satisfied: gwosc>=0.5.3 in c:\users\erick\anaconda3\lib\site-packages (from gwpy) (0.7.1)
# Requirement already satisfied: h5py>=3.0.0 in c:\users\erick\anaconda3\lib\site-packages (from gwpy) (3.9.0)
# Requirement already satisfied: ligo-segments>=1.0.0 in c:\users\erick\anaconda3\lib\site-packages (from gwpy) (1.4.0)
# Requirement already satisfied: ligotimegps>=1.2.1 in c:\users\erick\anaconda3\lib\site-packages (from gwpy) (2.0.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\erick\anaconda3\lib\site-packages (from gwpy) (3.9.2)
# Requirement already satisfied: numpy>=1.19 in c:\users\erick\anaconda3\lib\site-packages (from gwpy) (1.26.4)
# Requirement already satisfied: python-dateutil in c:\users\erick\anaconda3\lib\site-packages (from gwpy) (2.8.2)
# Requirement already satisfied: requests>=2.20.0 in c:\users\erick\anaconda3\lib\site-packages (from gwpy) (2.31.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\erick\anaconda3\lib\site-packages (from gwpy) (1.14.1)
# Requirement already satisfied: tqdm>=4.10.0 in c:\users\erick\anaconda3\lib\site-packages (from gwpy) (4.66.4)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\erick\anaconda3\lib\site-packages (from astropy>=4.3.0->gwpy) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.8.27.10.28.29 in c:\users\erick\anaconda3\lib\site-packages (from astropy>=4.3.0->gwpy) (0.2024.9.30.0.32.59)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\erick\anaconda3\lib\site-packages (from astropy>=4.3.0->gwpy) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in c:\users\erick\anaconda3\lib\site-packages (from astropy>=4.3.0->gwpy) (23.1)
# Requirement already satisfied: pytz in c:\users\erick\anaconda3\lib\site-packages (from dateparser>=1.1.4->gwpy) (2023.3.post1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in c:\users\erick\anaconda3\lib\site-packages (from dateparser>=1.1.4->gwpy) (2023.10.3)
# Requirement already satisfied: tzlocal in c:\users\erick\anaconda3\lib\site-packages (from dateparser>=1.1.4->gwpy) (2.1)
# Requirement already satisfied: igwn-auth-utils>=0.3.1 in c:\users\erick\anaconda3\lib\site-packages (from gwdatafind>=1.1.0->gwpy) (1.1.1)
# Requirement already satisfied: six in c:\users\erick\anaconda3\lib\site-packages (from ligo-segments>=1.0.0->gwpy) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib>=3.3.0->gwpy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib>=3.3.0->gwpy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib>=3.3.0->gwpy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib>=3.3.0->gwpy) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib>=3.3.0->gwpy) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\erick\anaconda3\lib\site-packages (from matplotlib>=3.3.0->gwpy) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\erick\anaconda3\lib\site-packages (from requests>=2.20.0->gwpy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\erick\anaconda3\lib\site-packages (from requests>=2.20.0->gwpy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\erick\anaconda3\lib\site-packages (from requests>=2.20.0->gwpy) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\erick\anaconda3\lib\site-packages (from requests>=2.20.0->gwpy) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\erick\anaconda3\lib\site-packages (from tqdm>=4.10.0->gwpy) (0.4.6)
# Requirement already satisfied: cryptography>=2.3 in c:\users\erick\anaconda3\lib\site-packages (from igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (42.0.2)
# Requirement already satisfied: safe-netrc>=1.0.0 in c:\users\erick\anaconda3\lib\site-packages (from igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (1.0.1)
# Requirement already satisfied: scitokens>=1.7.0 in c:\users\erick\anaconda3\lib\site-packages (from igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (1.8.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\erick\anaconda3\lib\site-packages (from cryptography>=2.3->igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (1.16.0)
# Requirement already satisfied: PyJWT>=1.6.1 in c:\users\erick\anaconda3\lib\site-packages (from scitokens>=1.7.0->igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (2.4.0)
# Requirement already satisfied: pycparser in c:\users\erick\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.3->igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (2.21)

# %%
import gwpy
print(gwpy.__version__)
import astropy
print(astropy.__version__)
# %matplotlib inline
# Out:
# 3.0.10
# 6.1.4

# %%
from gwosc import datasets
from gwosc.datasets import find_datasets
import matplotlib.pyplot as plt

# %% [markdown]
# exists some **parameters** that we can use, like: **type; events, runs, or catalogs**

# %% [markdown]
# the **type** parameters show the others, and you can choose one of these to filter

# %%
catalogs = datasets.find_datasets(type='catalogs')
catalogs
# Out:
# ['GWTC',
#  'GWTC-1-confident',
#  'GWTC-1-marginal',
#  'GWTC-2',
#  'GWTC-2.1-auxiliary',
#  'GWTC-2.1-confident',
#  'GWTC-2.1-marginal',
#  'GWTC-3-confident',
#  'GWTC-3-marginal',
#  'Initial_LIGO_Virgo',
#  'O1_O2-Preliminary',
#  'O3_Discovery_Papers',
#  'O3_IMBH_marginal',
#  'O4_Discovery_Papers']

# %%
events = datasets.find_datasets(type='events', catalog = 'GWTC-1-confident')
events
# Out:
# ['GW150914-v3',
#  'GW151012-v3',
#  'GW151226-v2',
#  'GW170104-v2',
#  'GW170608-v3',
#  'GW170729-v1',
#  'GW170809-v1',
#  'GW170814-v3',
#  'GW170817-v3',
#  'GW170818-v1',
#  'GW170823-v1']

# %% [markdown]
# now we know how get some specific event, in some catalog. So we can find the **gps time** for this event and use this to plot its time series

# %%
from gwosc.datasets import event_gps, event_at_gps

# %%
gps = event_gps('GW150914-v3')
gps
# Out:
# 1126259462.4

# %% [markdown]
# its possible to make the inverse process too

# %%
event_before = event_at_gps(1126259462.4)
event_before
# Out:
# 'GW150914'

# %% [markdown]
# we have the gps time, so we need select some interval around of these time

# %%
segment = (int(gps)-100, int(gps)+100)
segment
# Out:
# (1126259362, 1126259562)

# %% [markdown]
# using the TimeSeries function from the gwpy.timeseries library

# %%
from gwpy.timeseries import TimeSeries

# %%
ldata = TimeSeries.fetch_open_data('L1', *segment, cache=True, verbose=True)
print(ldata)
# Out:
# Fetched 1 URLs from gwosc.org for [1126259362 .. 1126259562))
# Reading data... [Done]
# TimeSeries([-1.37598861e-18, -1.43014661e-18, -1.46035763e-18,
#             ..., -9.97733204e-19, -9.91026903e-19,
#             -9.85563289e-19]
#            unit: dimensionless,
#            t0: 1126259362.0 s,
#            dt: 0.000244140625 s,
#            name: Strain,
#            channel: None)

# %%
plot = ldata.plot()
# Out:
# <Plot size 1200x400 with 1 Axes>

# %% [markdown]
# this is our signal in interval (-100,100) around the gps time

# %% [markdown]
# now we will use the Hann window, a smoothing function used to avoid unwanted effects such as spectral leakage when performing Fourier transforms

# %% [markdown]
# **if we do not use the Hann window**, our spectrum after the transform would be as below, where the data is wider at the ends and narrower in the center

# %%
fft = ldata.fft()

# %%
plot = fft.abs().plot(xscale="log", yscale="log")

axfft =plot.gca()
axfft.set_xlim(10, 1500)
axfft.set_ylim(0.4e-26,1e-19)
plot.show()
# Out:
# <Plot size 640x480 with 1 Axes>

# %% [markdown]
# A janela de Hann é uma função matemática que suaviza as extremidades dos dados aplicando valores que vão de 0 nas bordas até 1 no centro. Isso ajuda a reduzir os efeitos de descontinuidade quando os dados são transformados, por exemplo, usando uma FFT. Sua função é da seguinte forma

# %% [markdown]
# $$ w_{n} = 0.5(1-cos\left(\frac{2\pi n}{N-1}\right)), \hspace{1cm} n = 0, 1, 2, ..., N-1$$

# %%
from scipy.signal import get_window

N = 100  # Tamanho da janela
window = get_window('hann', N)

plt.plot(window)
plt.title('Janela de Hann')
plt.show()

# %% [markdown]
# **So, applying the Hann window to the ( ldata )** data and subsequently the transform, we have:

# %%
window = get_window('hann', ldata.size)
lwin = ldata * window

# %% [markdown]
# now we can use the Fourier transform to smooting and cut our frequency range that we need

# %%
fftamp = lwin.fft().abs()
plot = fftamp.plot(xscale="log", yscale="log")

limfftamp = plot.gca()

# Definir os limites dos eixos
limfftamp.set_xlim(10, 1500)
limfftamp.set_ylim(0.4e-26, 1e-19)

#Mostrar o gráfico
plot.show()
# Out:
# <Plot size 640x480 with 1 Axes>

# %% [markdown]
# Now we can see what the noises look like for this frequency range

# %%
asd = ldata.asd(fftlength=3)
plot = asd.plot()

ax = plot.gca()
ax.set_title('ASD')
ax.set_ylabel(r'Strain [1$/\sqrt{\mathrm{Hz}}$]')
ax.set(xlim=(15, 1500), ylim=(0.4e-23, 1e-20))
# Out:
# [(15, 1500), (4e-24, 1e-20)]
# <Plot size 640x480 with 1 Axes>

# %% [markdown]
# the "strain" mean the amplitudes of these noises. We note that the strain noises are small than the strain from the GW, whose amplitudes order are $10^{-21}$ meters

# %% [markdown]
# now we will see the frequency behavior as a function of time

# %%
# para Hanford data
hdata2 = TimeSeries.fetch_open_data('H1', *segment, cache=True)

# %%
from gwosc.datasets import event_at_gps
from gwpy.timeseries import TimeSeriesBase

gps = event_gps('GW150914-v3')
print("GW150914 GPS:", gps)

segment2 = (int(gps) -16, int(gps)+16)
hdata = TimeSeries.fetch_open_data('H1', *segment2, verbose = True, cache=True )
# Out:
# GW150914 GPS: 1126259462.4
# Fetched 1 URLs from gwosc.org for [1126259446 .. 1126259478))
# Reading data... [Done]

# %%
hq = hdata.q_transform(frange=(30, 500), outseg=(gps-0.2,gps+0.1))
plot = hq.plot()
ax = plot.gca()
ax.set_epoch(gps)
ax.set_yscale('log')
ax.colorbar(label="Normalised energy")
